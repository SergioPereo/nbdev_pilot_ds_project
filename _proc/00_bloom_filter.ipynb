# %% [raw]
# ---
# description: Data structures module. It contains the DS's implementations of the library.
# output-file: bloom_filter.html
# title: Data Structures
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(BloomFilter)
# Out:
# ---
#
# ### BloomFilter
#
# >      BloomFilter (m=10, k=1)
#
# Bloom filter description
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | m | int | 10 | m description |
# | k | int | 1 | k description |
